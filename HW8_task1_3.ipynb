# %%
# 1) Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks):
# zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110],
# ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832].
# Найдите ковариацию этих двух величин с помощью элементарных действий, а затем с помощью функции cov из numpy
# Полученные значения должны быть равны.
# Найдите коэффициент корреляции Пирсона с помощью ковариации 
# и среднеквадратичных отклонений двух признаков, а затем с использованием функций из библиотек numpy и pandas.

import numpy as np
zp=np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks=np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
cov1=np.mean(zp*ks)-np.mean(zp)*np.mean(ks)
print(cov1)
cov2=np.cov(zp,ks,ddof=0)
print(cov2)
#При смещённой ковариации значения посчитанной ковариации вручную и с помощью функции равны

std1=np.std(zp,ddof=0)
std2=np.std(ks,ddof=0)
r1=cov2/(std1*std2)
print(f'Коэффициент корреляции посчитан с помощью помощью ковариации и среднеквадратичных отклонений двух признаков {r1}')
r2=np.corrcoef(zp,ks)
print(f'Коэффициент корреляции посчитан с помощью помощью функции {r2}')
# Out:
# 9157.839999999997
# [[ 3494.64  9157.84]
#  [ 9157.84 30468.89]]
# Коэффициент корреляции посчитан с помощью помощью ковариации и среднеквадратичных отклонений двух признаков [[0.33866702 0.88749009]
#  [0.88749009 2.95275283]]
# Коэффициент корреляции посчитан с помощью помощью функции [[1.         0.88749009]
#  [0.88749009 1.        ]]

# %%
# 2) Измерены значения IQ выборки студентов,
# обучающихся в местных технических вузах:
# 131, 125, 115, 122, 131, 115, 107, 99, 125, 111.
# Известно, что в генеральной совокупности IQ распределен нормально.
# Найдите доверительный интервал для математического ожидания с надежностью 0.95.
import numpy as np
import scipy.stats as stats
iq=np.array([131, 125, 115, 122, 131, 115, 107, 99, 125, 111])
av=np.mean(iq)
d=np.var(iq,ddof=1)
t=stats.t.ppf(0.975,9)
iq1=av-t*np.sqrt(d/10)
iq2=av+t*np.sqrt(d/10)
print(iq1)
print(iq2)
print(f'Доверительный интервал для мат ожидания с надежностью 0,95 [110.55;125.64]')
# Out:
# 110.55608365158724
# 125.64391634841274
# Доверительный интервал для мат ожидания с надежностью 0,95 [110.55;125.64]

# %%
# 3) Известно, что рост футболистов в сборной распределен нормально с дисперсией генеральной совокупности, 
# равной 25 кв.см. Объем выборки равен 27, среднее выборочное составляет 174.2. 
# Найдите доверительный интервал для математического ожидания с надежностью 0.95.

import numpy as np
import scipy.stats as stats
X=174.2
n=27
d=25
Z=stats.norm.ppf(0.975)
print(Z)
x1=X-Z*np.sqrt(d/27)
x2=X+Z*np.sqrt(d/27)
print(x1)
print(x2)
print(f'Доверительный интервал для мат ожидания с надежностью 0,95 [172.31;176.09]')
# Out:
# 1.959963984540054
# 172.3140237765397
# 176.08597622346028
# Доверительный интервал для мат ожидания с надежностью 0,95 [172.31;176.09]
